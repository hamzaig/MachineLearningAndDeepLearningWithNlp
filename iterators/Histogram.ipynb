# %%
import matplotlib.pyplot as plt

age=[2,33,35,7,34,12,6,45,13,36,764,23,54,5,4,7,234,7,45,23,4,67,56,23,234,34,36]
range=(0,100)
bin=10
plt.hist(age,bin,range,rwidth=0.7)
plt.xlabel("xaxis")
plt.ylabel("yaxis")
plt.title("Histogram")
plt.show()
