# %%
import matplotlib.pyplot as plt
activities=['Eat','Sleep','Work','Play']
slices=[3,7,8,6]
color=['r','g','b','m']
plt.pie(slices,labels=activities,colors=color,startangle=90,shadow=True,explode=(0,0.1,0,0)
       ,autopct="%1.2f%%")
plt.legend()
plt.show()
